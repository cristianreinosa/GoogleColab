# %%
import pandas as pd

# %% [markdown]
# Creo la DataFrame

# %%
df = pd.DataFrame({"Marca":["Mazda","Renault","Toyota","Audi","Suzuki","Bmw","Ford","Mercedes Benz","Seat","Honda","Kia","Lexus","chevrolet","Hyundai","Foton"]})

# %%
df
# Out:
#             Marca
# 0           Mazda
# 1         Renault
# 2          Toyota
# 3            Audi
# 4          Suzuki
# 5             Bmw
# 6            Ford
# 7   Mercedes Benz
# 8            Seat
# 9           Honda
# 10            Kia
# 11          Lexus
# 12      chevrolet
# 13        Hyundai
# 14          Foton

# %% [markdown]
# Creo la segunda DataFrame

# %%
df = pd.DataFrame({"Marca":["Mazda","Renault","Toyota","Audi","Suzuki","Bmw","Ford","Mercedes Benz","Seat","Honda","Kia","Lexus","chevrolet","Hyundai","Foton"],"Color":["Negro","Azul","Blanco","Rojo","Verde","Amarillo","Gris","Marron","Rosado","Negro","Azul Oscuro","Blanco Perlado","Rojo Mate","Negro","Blanco"]})

# %%
df
# Out:
#             Marca           Color
# 0           Mazda           Negro
# 1         Renault            Azul
# 2          Toyota          Blanco
# 3            Audi            Rojo
# 4          Suzuki           Verde
# 5             Bmw        Amarillo
# 6            Ford            Gris
# 7   Mercedes Benz          Marron
# 8            Seat          Rosado
# 9           Honda           Negro
# 10            Kia     Azul Oscuro
# 11          Lexus  Blanco Perlado
# 12      chevrolet       Rojo Mate
# 13        Hyundai           Negro
# 14          Foton          Blanco

# %% [markdown]
# Creo la 3 y 4 DataFrame

# %%
df = pd.DataFrame({"Marca":["Mazda","Renault","Toyota","Audi","Suzuki","Bmw","Ford","Mercedes Benz","Seat","Honda","Kia","Lexus","chevrolet","Hyundai","Foton"],"Color":["Negro","Azul","Blanco","Rojo","Verde","Amarillo","Gris","Marron","Rosado","Negro","Azul Oscuro","Blanco Perlado","Rojo Mate","Negro","Blanco"],"Precio":[35000000,123000000,32000000,25000000,37000000,51000000,48000000,22000000,61000000,33000000,16000000,24000000,41000000,14000000,26000000],"Motor":["2000cc","2500cc","3000cc","1200cc","1500cc","2000cc","2500cc","2100cc","3500cc","1600cc","1800cc","2300cc","3200cc","1250cc","2000cc"]})

# %%
df
# Out:
#             Marca           Color     Precio   Motor
# 0           Mazda           Negro   35000000  2000cc
# 1         Renault            Azul  123000000  2500cc
# 2          Toyota          Blanco   32000000  3000cc
# 3            Audi            Rojo   25000000  1200cc
# 4          Suzuki           Verde   37000000  1500cc
# 5             Bmw        Amarillo   51000000  2000cc
# 6            Ford            Gris   48000000  2500cc
# 7   Mercedes Benz          Marron   22000000  2100cc
# 8            Seat          Rosado   61000000  3500cc
# 9           Honda           Negro   33000000  1600cc
# 10            Kia     Azul Oscuro   16000000  1800cc
# 11          Lexus  Blanco Perlado   24000000  2300cc
# 12      chevrolet       Rojo Mate   41000000  3200cc
# 13        Hyundai           Negro   14000000  1250cc
# 14          Foton          Blanco   26000000  2000cc

# %% [markdown]
# Usamos loc para ver la posicion que queremos ver

# %%
df[['Marca','Motor']]
# Out:
#             Marca   Motor
# 0           Mazda  2000cc
# 1         Renault  2500cc
# 2          Toyota  3000cc
# 3            Audi  1200cc
# 4          Suzuki  1500cc
# 5             Bmw  2000cc
# 6            Ford  2500cc
# 7   Mercedes Benz  2100cc
# 8            Seat  3500cc
# 9           Honda  1600cc
# 10            Kia  1800cc
# 11          Lexus  2300cc
# 12      chevrolet  3200cc
# 13        Hyundai  1250cc
# 14          Foton  2000cc

# %%
df.loc[5]
# Out:
# Marca          Bmw
# Color     Amarillo
# Precio    51000000
# Motor       2000cc
# Name: 5, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Marca   15 non-null     object
#  1   Color   15 non-null     object
#  2   Precio  15 non-null     int64
#  3   Motor   15 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 608.0+ bytes

# %%
df2 = pd.read_csv('cars.csv')

# %% [markdown]
# # Nueva sección

# %% [markdown]
# # Nueva sección

# %% [markdown]
# # Nueva sección

# %%
df2
# Out:
#          cliente  Cantidad     Medio_pago
# 0     Juan perez         1       Efectivo
# 1    Pepito Ruiz         2  Transferencia
# 2   Maria Castro         1       Efectivo
# 3          Cesde         5        Credito
# 4       Cristian         2        Credito
# 5         Susana         1       Efectivo
# 6       Samantha         2  Fransferencia
# 7          Eliza         4        Credito
# 8         Carlos         2       Efectico
# 9         Manuel         1        Credito
# 10       Daniela         3  Transferencia
# 11         Diego         5       Efectivo
# 12       Isabela         3        Credito
# 13        Daniel         2  Transferencia
# 14         Dario         1       Efectivo

# %%
df3 = pd.concat([df,df2],axis=1)

# %%
df3
# Out:
#             Marca           Color     Precio   Motor       cliente  Cantidad  \
# 0           Mazda           Negro   35000000  2000cc    Juan perez         1
# 1         Renault            Azul  123000000  2500cc   Pepito Ruiz         2
# 2          Toyota          Blanco   32000000  3000cc  Maria Castro         1
# 3            Audi            Rojo   25000000  1200cc         Cesde         5
# 4          Suzuki           Verde   37000000  1500cc      Cristian         2
# 5             Bmw        Amarillo   51000000  2000cc        Susana         1
# 6            Ford            Gris   48000000  2500cc      Samantha         2
# 7   Mercedes Benz          Marron   22000000  2100cc         Eliza         4
# 8            Seat          Rosado   61000000  3500cc        Carlos         2
# 9           Honda           Negro   33000000  1600cc        Manuel         1
# 10            Kia     Azul Oscuro   16000000  1800cc       Daniela         3
# ...
