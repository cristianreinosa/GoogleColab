# %% [markdown]
# # Analisis de Alquiler para Nuevas Tecnologias CESDE

# %%
import pandas as pd

# %%
info_alquiler = pd.read_csv('alquiler.csv', sep =(';'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c9bfa419ee8c> in <cell line: 1>()
# ----> 1 info_alquiler = pd.read_csv('alquiler.csv', sep =(';'))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
info_alquiler.shape
# Out:
# (32960, 9)

# %%
info_alquiler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
info_alquiler.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...

# %% [markdown]
# Con head() es una funcion que permite imprimir los primeros datos del data frame, 5 sin parametro o con los que desee pasando el valor como parametro

# %%
info_alquiler.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %% [markdown]
# Con el metodo tail() nos muestra los ultimos 10 de la data frame

# %%
info_alquiler.tail(10)
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 32950        Departamento   San Miguel        1         0       0    28
# 32951        Departamento          Ate        2         0       0    52
# 32952  Casa en condominio          Ate        5         3       4   450
# 32953        Departamento  Santa Anita        2         0       0    70
# 32954             Cochera   Pachacámac        0         0       0   755
# 32955          Habitación   Pachacámac        0         0       0    27
# 32956        Departamento        Lince        3         1       2    78
# 32957        Departamento        Rímac        2         1       0    48
# 32958        Departamento        Rímac        2         0       0    70
# 32959     Local comercial   Pachacámac        0         0       0   250
#
#          Valor  Mantenimiento  Impuesto
# 32950   1000.0          360.0      25.0
# 32951   1000.0          550.0       NaN
# 32952  15000.0         1711.0    2332.0
# ...

# %% [markdown]
# para saber que districtos o que es m lo que tiene la data frame con el metodo list(').drop_duplicates para que no me duplique los tipos

# %%
list(info_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
list(info_alquiler['Distrito'].drop_duplicates())
# Out:
# ['San Borja',
#  'Lurigancho',
#  'Ate',
#  'Pachacámac',
#  'Barranco',
#  'Comas',
#  'El Agustino',
#  'Mi Perú',
#  'Chorrillos',
#  'San Luis',
#  'Callao',
#  'San Miguel',
#  'Santa Rosa',
#  'Rímac',
#  'Punta Negra',
#  'Lince',
#  'Jesús María',
#  'Miraflores',
#  'Breña',
#  'Ancón',
#  'Santa Anita',
#  'Villa María del Triunfo',
#  'Villa El Salvador',
#  'Punta Hermosa',
#  'La Perla',
#  'San Juan de Lurigancho',
#  'Chaclacayo',
#  'Pueblo Libre',
#  'Puente Piedra',
#  'Lurín',
#  'La Punta',
#  'Ventanilla',
#  'Magdalena del Mar',
#  'Santa María del Mar',
#  'Bellavista',
#  'San Martín de Porres',
#  'Santiago de Surco',
#  'San Juan de Miraflores',
#  'San Isidro',
#  'San Bartolo',
#  'Carmen de La Legua',
#  'Los Olivos',
#  'Pucusana',
#  'La Molina',
#  'Cieneguilla',
#  'Lima',
#  'Independencia',
#  'Surquillo',
#  'La Victoria',
#  'Carabayllo']

# %%
Viviendas = ['Habitacion',
 'Casa',
 'Departamento',
 'Casa en condominio',
 'Casa de villa',
 'Cochera',
 'Loft',
 'Chalet',
 'Studio',]

# %%
Viviendas
# Out:
# ['Habitacion',
#  'Casa',
#  'Departamento',
#  'Casa en condominio',
#  'Casa de villa',
#  'Cochera',
#  'Loft',
#  'Chalet',
#  'Studio']

# %%
info_viviendas = info_alquiler['Tipo'].isin(Viviendas)

# %%
info_viviendas
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955    False
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
datos_viviendas = info_alquiler[info_viviendas]

# %%
datos_viviendas
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 1              Casa   Lurigancho        2         0       1   100   7000.0
# 3      Departamento   Pachacámac        1         0       0    15    800.0
# 4      Departamento          Ate        1         0       0    48    800.0
# 5      Departamento     Barranco        3         1       0    70   1200.0
# 6      Departamento        Comas        2         0       0    50   1300.0
# ...             ...          ...      ...       ...     ...   ...      ...
# 32953  Departamento  Santa Anita        2         0       0    70    900.0
# 32954       Cochera   Pachacámac        0         0       0   755  14000.0
# 32956  Departamento        Lince        3         1       2    78   1800.0
# 32957  Departamento        Rímac        2         1       0    48   1400.0
# 32958  Departamento        Rímac        2         0       0    70   3000.0
#
#        Mantenimiento  Impuesto
# 1                NaN       NaN
# ...

# %%
datos_viviendas.shape
# Out:
# (21882, 9)

# %%
datos_viviendas.index = range(datos_viviendas.shape[0])

# %%
datos_viviendas.head(30)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0                 Casa   Lurigancho        2         0       1   100   7000.0
# 1         Departamento   Pachacámac        1         0       0    15    800.0
# 2         Departamento          Ate        1         0       0    48    800.0
# 3         Departamento     Barranco        3         1       0    70   1200.0
# 4         Departamento        Comas        2         0       0    50   1300.0
# 5   Casa en condominio          Ate        5         4       5   750  22000.0
# 6   Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7         Departamento   Pachacámac        1         0       0    36   1200.0
# 8         Departamento      Mi Perú        2         1       0    70   1500.0
# 9         Departamento    San Borja        3         1       1    90   1500.0
# 10        Departamento    San Borja        1         0       1    40   2000.0
# ...

# %%
datos_viviendas.to_csv('alquileres_viviendas.csv',)
